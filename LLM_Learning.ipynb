# %%
# !pip install nltk scikit-learn
import nltk
import string
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

def preprocess(text):
  text = text.lower()
  print(text)
  text = text.translate(str.maketrans("", "", string.punctuation))
  print(text)
  words=word_tokenize(text)
  print(words)

  clean_words=[]
  for i in words:
    if i not in stop_words:
      lemma= lemmatizer.lemmatize(i)
      clean_words.append(lemma)

  print("\nAfter Stopword Removal and lemmitization:")
  print(clean_words)


  return clean_words



text = "The doctors were treating patients while the children were playing with cars."
tokens = preprocess(text)

print("\nReturned:", tokens)
# Out:
# ...
# the doctors were treating patients while the children were playing with cars.
# the doctors were treating patients while the children were playing with cars
# ['the', 'doctors', 'were', 'treating', 'patients', 'while', 'the', 'children', 'were', 'playing', 'with', 'cars']
#
# After Stopword Removal:
# ['doctor', 'treating', 'patient', 'child', 'playing', 'car']
#
# Returned: ['doctor', 'treating', 'patient', 'child', 'playing', 'car']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# !pip install nltk scikit-learn
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import WordNetLemmatizer

art = """
Artificial Intelligence is transforming healthcare.
Doctors use AI to detect diseases early.
Patients receive faster treatment because of AI.
Machine learning helps researchers discover new medicines.
The future of healthcare looks very promising.
"""

senty=sent_tokenize(art)
vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(senty)

print("Vocabulary:")
print(vectorizer.get_feature_names_out())

print("\nMatrix Shape:")
print(tfidf_matrix.shape)
tfidf_array = tfidf_matrix.toarray()
print("\nTF-IDF Matrix:")
print(tfidf_array)
sentence_scores = np.sum(tfidf_array, axis=1)
for i, score in enumerate(sentence_scores):
    print(f"Sentence {i+1}: {score:.3f}")

np.argsort()
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Vocabulary:
# ['ai' 'artificial' 'because' 'detect' 'discover' 'diseases' 'doctors'
#  'early' 'faster' 'future' 'healthcare' 'helps' 'intelligence' 'is'
#  'learning' 'looks' 'machine' 'medicines' 'new' 'of' 'patients'
#  'promising' 'receive' 'researchers' 'the' 'to' 'transforming' 'treatment'
#  'use' 'very']
#
# Matrix Shape:
# (5, 30)
#
# TF-IDF Matrix:
# [[0.         0.46369322 0.         0.         0.         0.
#   0.         0.         0.         0.         0.37410477 0.
#   0.46369322 0.46369322 0.         0.         0.         0.
# ...

# %%
# !pip install nltk scikit-learn

import nltk
import string
import numpy as np

nltk.download("punkt")
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# -------------------------
# Preprocessing Function
# -------------------------
def preprocess(text):

    text = text.lower()

    text = text.translate(str.maketrans("", "", string.punctuation))

    words = word_tokenize(text)

    clean_words = []

    for word in words:
        if word not in stop_words:
            lemma = lemmatizer.lemmatize(word)
            clean_words.append(lemma)

    return clean_words


# -------------------------
# Article
# -------------------------
art = """
Artificial Intelligence is transforming healthcare.
Doctors use AI to detect diseases early.
Patients receive faster treatment because of AI.
Machine learning helps researchers discover new medicines.
The future of healthcare looks very promising.
"""

# -------------------------
# Sentence Tokenization
# -------------------------
senty = sent_tokenize(art)

print("Original Sentences:\n")

for sentence in senty:
    print(sentence)

# ====================================================
# NEW PART (Use your preprocess function)
# ====================================================

clean_sentences = []

for sentence in senty:

    tokens = preprocess(sentence)

    clean_sentence = " ".join(tokens)

    clean_sentences.append(clean_sentence)

print("\nPreprocessed Sentences:\n")

for sentence in clean_sentences:
    print(sentence)

# ====================================================
# TF-IDF
# ====================================================

vectorizer = TfidfVectorizer()

# CHANGE HERE
# Earlier you had:
# tfidf_matrix = vectorizer.fit_transform(senty)

# Now use clean_sentences

tfidf_matrix = vectorizer.fit_transform(clean_sentences)

print("\nVocabulary:\n")
print(vectorizer.get_feature_names_out())

print("\nMatrix Shape:")
print(tfidf_matrix.shape)

tfidf_array = tfidf_matrix.toarray()

print("\nTF-IDF Matrix:\n")
print(tfidf_array)

# ====================================================
# Sentence Scoring
# ====================================================

sentence_scores = np.sum(tfidf_array, axis=1)

print("\nSentence Scores:\n")

for i, score in enumerate(sentence_scores):
    print(f"Sentence {i+1}: {score:.3f}")

# ====================================================
# Ranking
# ====================================================

top_indices = np.argsort(sentence_scores)[::-1]

top_n = 2

top_sentences = top_indices[:top_n]

# Keep original order
top_sentences = sorted(top_sentences)

# ====================================================
# Summary
# ====================================================

print("\nFinal Summary:\n")

for index in top_sentences:
    print(senty[index])
